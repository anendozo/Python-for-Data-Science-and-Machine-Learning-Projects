# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Finance Data Project
#
# In this data project we will focus on exploratory data analysis of stock prices. Keep in mind, this project is just meant to practice your visualization and pandas skills, it is not meant to be a robust financial analysis or be taken as financial advice.
# ____
# **NOTE: This project is extremely challenging because it will introduce a lot of new concepts and have you looking things up on your own (we'll point you in the right direction) to try to solve the tasks issued.**
#
# We'll focus on bank stocks and see how they progressed throughout the [financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to early 2016.

# %% [markdown]
# ## Get the Data
#
# In this section we will learn how to use pandas to directly read data from Google finance using pandas!
#
# First we need to start with the proper imports, which we've already laid out for you here.
#
# *Note: [You'll need to install pandas-datareader for this to work!](https://github.com/pydata/pandas-datareader) Pandas datareader allows you to [read stock information directly from the internet](http://pandas.pydata.org/pandas-docs/stable/remote_data.html) Use these links for install guidance (**pip install pandas-datareader**), or just follow along with the video lecture.*
#
# ### The Imports
#
# Already filled out for you.

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %%
import seaborn as sns

# %%
sns.set_style('whitegrid')

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data
#
# We need to get data using pandas datareader. We will get stock information for the following banks:
# *  Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# **Figure out how to get the stock data from Jan 1st 2006 to Jan 1st 2016 for each of these banks. Set each bank to be a separate dataframe, with the variable name for that bank being its ticker symbol. This will involve a few steps:**
# 1. Use datetime to set start and end datetime objects.
# 2. Figure out the ticker symbol for each bank.
# 2. Figure out how to use datareader to grab info on the stock.
#
# **Use [this documentation page](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html) for hints and instructions (it should just be a matter of replacing certain values. Use google finance as a source, for example:**
#
#     # Bank of America
#     BAC = data.DataReader("BAC", 'google', start, end)
#
# ### WARNING: MAKE SURE TO CHECK THE LINK ABOVE FOR THE LATEST WORKING API. "google" MAY NOT ALWAYS WORK.
# ------------
# ### We also provide pickle file in the article lecture right before the video lectures.

# %%
start=datetime.datetime(2006,1,1)

# %%
end=datetime.datetime(2016,1,1)

# %%
BAC = data.DataReader('BAC', 'stooq',start,end).sort_index()

# %%
C = data.DataReader('C', 'stooq',start,end).sort_index()

# %%
GS = data.DataReader('GS', 'stooq',start,end).sort_index()

# %%
JPM = data.DataReader('JPM', 'stooq',start,end).sort_index()

# %%
MS = data.DataReader('MS', 'stooq',start,end).sort_index()

# %%
WFC = data.DataReader('WFC', 'stooq',start,end).sort_index()

# %% [markdown]
# ** Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers**

# %%
tickers= ['BAC','C','GS','JPM','MS','WFC']

# %%
tickers
# Out:
# ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %% [markdown]
# **Use pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks. Set the keys argument equal to the tickers list. Also pay attention to what axis you concatenate on.**

# %%
bank_stocks=pd.concat([BAC,C,GS,JPM,MS,WFC], axis=1, keys=tickers)

# %% [markdown]
# **Set the column name levels (this is filled out for you):**

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %% [markdown]
# **Check the head of the bank_stocks dataframe.**

# %% [markdown]
# * Open= Opening price of the stock on that day
# * High= Highest price
# * Low= Lowest price
# * Close= Closing price
# * Volume= How many stocks are traded in that day

# %%
bank_stocks.head()
# Out:
# Bank Ticker      BAC                                                 C  \
# Stock Info      Open     High      Low    Close        Volume     Open
# Date
# 2006-01-03   39.4871  39.7023  38.8390  39.6217  1.936396e+07  405.492
# 2006-01-04   39.5549  39.7592  39.0904  39.2004  2.110031e+07  404.358
# 2006-01-05   39.2004  39.4126  38.9834  39.2525  1.761312e+07  400.843
# 2006-01-06   39.3850  39.4774  39.0089  39.1917  1.496529e+07  404.504
# 2006-01-09   39.3182  39.5294  39.0158  39.2181  1.855918e+07  402.174
#
# Bank Ticker                                           ...       MS           \
# Stock Info      High      Low    Close        Volume  ...     Open     High
# Date                                                  ...
# 2006-01-03   408.615  398.112  407.891  1.858097e+06  ...  37.4934  38.3558
# 2006-01-04   406.325  400.089  400.354  2.260921e+06  ...  38.4971  38.8778
# 2006-01-05   403.663  400.520  402.321  1.371893e+06  ...  38.2675  38.4264
# ...

# %% [markdown]
# Since the data extracted from Stooq Index data is not the same as in the pickle file provided for the project, we'll use the provided pickle file to get the same answer moving forward

# %%
bank_stocks= pd.read_pickle('all_banks')

# %%
bank_stocks.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker           ...     MS                                  WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close   Volume   Open   High
# Date                  ...
# 2006-01-03   1537660  ...  57.17  58.49  56.74  58.31  5377000  31.60  31.98
# 2006-01-04   1871020  ...  58.70  59.28  58.35  58.35  7977800  31.80  31.82
# 2006-01-05   1143160  ...  58.55  58.59  58.02  58.51  5778000  31.50  31.56
# ...

# %% [markdown]
# # EDA
#
# Let's explore the data a bit! Before continuing, I encourage you to check out the documentation on [Multi-Level Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html) and [Using .xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html).
# Reference the solutions if you can not figure out how to use .xs(), since that will be a major part of this project.
#
# **What is the max Close price for each bank's stock throughout the time period?**

# %%
bank_stocks.xs(key='Close', axis=1,level=1).max()
# Out:
# Bank Ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# dtype: float64

# %% [markdown]
# **Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns=pd.DataFrame()

# %%
returns
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# **We can use pandas pct_change() method on the Close column to create a column representing this return value. Create a for loop that goes and for each Bank Stock Ticker creates this returns column and set's it as a column in the returns DataFrame.**

# %%
close=bank_stocks.xs(key='Close', axis=1,level=1)
close.head()
# Out:
# Bank Ticker    BAC      C      GS    JPM     MS    WFC
# Date
# 2006-01-03   47.08  492.9  128.87  40.19  58.31  31.90
# 2006-01-04   46.58  483.8  127.09  39.62  58.35  31.53
# 2006-01-05   46.64  486.2  127.04  39.74  58.51  31.50
# 2006-01-06   46.57  486.2  128.84  40.02  58.57  31.68
# 2006-01-09   46.60  483.9  130.39  40.67  59.19  31.68

# %%
returns=close.pct_change()

# %%
returns.columns.names=['']

# %%
returns.columns= returns.columns +' Return'

# %%
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.000951
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005714
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586    0.000000

# %%
returns_option=pd.DataFrame()

# %%
#alternative
for tick in tickers:
    returns_option[tick + ' Return']= bank_stocks[tick]['Close'].pct_change()

# %%
returns_option.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.000951
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005714
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586    0.000000

# %% [markdown]
# **Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?**

# %%
sns.pairplot(returns, diag_kind='hist', diag_kws={'bins':10})

# %% [markdown]
# There's an almost a straightline in C returns (low return) bec. CitiGroup actually had a huge stock crash

# %% [markdown]
# * See solution for details about Citigroup behavior....

# %% [markdown]
# **Using this returns DataFrame, figure out on what dates each bank stock had the best and worst single day returns. You should notice that 4 of the banks share the same day for the worst drop, did anything significant happen that day?**

# %%
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2011-05-06
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2011-05-09
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %%
pd.concat([returns.idxmax(),returns.max(), returns.idxmin(), returns.min()], axis=1, keys=['Max Date','Max Returns', 'Min Date', 'Min Returns'])
# Out:
#              Max Date  Max Returns   Min Date  Min Returns
#
# BAC Return 2009-04-09     0.352691 2009-01-20    -0.289694
# C Return   2011-05-09     8.769912 2011-05-06    -0.899107
# GS Return  2008-11-24     0.264678 2009-01-20    -0.189596
# JPM Return 2009-01-21     0.250967 2009-01-20    -0.207274
# MS Return  2008-10-13     0.869835 2008-10-09    -0.258929
# WFC Return 2008-07-16     0.327645 2009-01-20    -0.238223

# %% [markdown]
# **You should have noticed that Citigroup's largest drop and biggest gain were very close to one another, did anything significant happen in that time frame?**
#
# Effective on May 6, 2011, Citigroup announces reverse stock split

# %% [markdown]
# **Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015?**

# %% [markdown]
# A high standard deviation shows that the data is widely spread (less reliable) and a low standard deviation shows that the data are clustered closely around the mean (more reliable).
#
# A high STD means the price goes up and down a lot versus a small STD which means the price is steady

# %%
returns.std() #CitiGroup is the riskiest over the entire period since it has the highest standard deviation so it's less reliable
# Out:
# BAC Return    0.036650
# C Return      0.179969
# GS Return     0.025346
# JPM Return    0.027656
# MS Return     0.037820
# WFC Return    0.030233
# dtype: float64

# %%
returns.loc['2015'].std() #MS or BAC is the riskiest for 2015 since it has the highest std(less reliable)
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %%
returns.loc['2015-01-01': '2015-12-31'].std()
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %% [markdown]
# **Create a distplot using seaborn of the 2015 returns for Morgan Stanley **

# %%
sns.displot(returns.loc['2015']['MS Return'], kde=True, bins=100, color='green')
#stable; only deviates at 0.06 from the mean

# %% [markdown]
# **Create a distplot using seaborn of the 2008 returns for CitiGroup**

# %%
sns.displot(returns.loc['2008']['C Return'],kde=True, bins=100, color='red')
#0.6 is an outlier

# %%
plt.figure(figsize=(15,4))
sns.kdeplot(returns['GS Return'], color='green')
sns.kdeplot(returns['C Return'], color='red')
# Out:
# <AxesSubplot:xlabel='GS Return', ylabel='Density'>

# %% [markdown]
# A larger standard deviation indicates that the data is spread out around the mean; the normal distribution will be flatter and wider.
#
# GS return has lower STD than CitiGroup return
#
# * C Return      0.179969
# * GS Return     0.025346

# %% [markdown]
# ____
# # More Visualization
#
# A lot of this project will focus on visualizations. Feel free to use any of your preferred visualization libraries to try to recreate the described plots below, seaborn, matplotlib, plotly and cufflinks, or just pandas.
#
# ### Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
# import plotly
# import cufflinks as cf
# cf.go_offline()

# %%
#plotly
import chart_studio.plotly as py
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %% [markdown]
# **Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) to get a cross section of the data.)**

# %%
bank_stocks.xs('Close',axis=1,level=1).head()
# Out:
# Bank Ticker    BAC      C      GS    JPM     MS    WFC
# Date
# 2006-01-03   47.08  492.9  128.87  40.19  58.31  31.90
# 2006-01-04   46.58  483.8  127.09  39.62  58.35  31.53
# 2006-01-05   46.64  486.2  127.04  39.74  58.51  31.50
# 2006-01-06   46.57  486.2  128.84  40.02  58.57  31.68
# 2006-01-09   46.60  483.9  130.39  40.67  59.19  31.68

# %%
bank_stocks.xs('Close',axis=1,level=1).plot(figsize=(10,4))
plt.legend(loc='upper right')

# %% [markdown]
# This shows a huge crash for CitiGroup in 2008
#
# Goldman Sachs decreases and bounces back quickly after the recession

# %%
#alternative
for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick,figsize=(12,4))
plt.legend()

# %%
bank_stocks.xs('Close',axis=1,level=1).iplot()
# Out:
# <div>                            <div id="a466a821-49a4-4087-9f85-45785e96b4aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## Moving Averages
#
# Let's analyze the moving averages for these stocks in the year 2008.
#
# **Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
bac_close=bank_stocks.loc['2008'].xs(('BAC', 'Close'), axis=1).to_frame(name='BAC CLOSE')

# %%
bac_close['30 Day Avg']=bac_close.rolling(30).mean()

# %%
bac_close.head()
# Out:
#             BAC CLOSE  30 Day Avg
# Date
# 2008-01-02      40.56         NaN
# 2008-01-03      40.30         NaN
# 2008-01-04      39.85         NaN
# 2008-01-07      39.90         NaN
# 2008-01-08      38.41         NaN

# %%
bac_close.plot( figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.figure(figsize=(10,4))
bac_close=bank_stocks.loc['2008'].xs(('BAC', 'Close'), axis=1).rolling(30).mean().plot(label='30 Day Avg')
bac_close=bank_stocks.loc['2008'].xs(('BAC', 'Close'), axis=1).plot(label='BAC CLOSE')
plt.legend()

# %% [markdown]
# **Create a heatmap of the correlation between the stocks Close Price.**

# %%
sns.heatmap(close.corr(),annot=True, cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %% [markdown]
# **Optional: Use seaborn's clustermap to cluster the correlations together:**

# %%
sns.clustermap(close.corr(), annot=True, cmap='coolwarm',vmin=-1, vmax=1)

# %%
close.corr().iplot(kind='heatmap', colorscale='rdylbu')
# Out:
# <div>                            <div id="5bbb09f3-af79-4ec1-9982-955452e71514" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# JPM and WFC as well as MS and BAC are correlated w/ each other

# %% [markdown]
# # Part 2 (Optional)
#
# In this second part of the project we will rely on the cufflinks library to create some Technical Analysis plots. This part of the project is experimental due to its heavy reliance on the cuffinks project, so feel free to skip it if any functionality is broken in the future.

# %% [markdown]
# **Use .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**

# %%
bank_stocks[(bank_stocks.index >='2015-01-01') & (bank_stocks.index <= '2016-01-01')]['BAC'].iplot(kind='candle')
# Out:
# <div>                            <div id="c17bc8ee-6959-4726-8216-54ce4ae2b8d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# **Use .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.**

# %%
bank_stocks.loc['2015'].xs(('MS','Close'), axis=1).ta_plot(study='sma', periods=[13,21,55])
#technical analysis plot
# Out:
# <div>                            <div id="a77f378d-d23a-4e9e-baf4-1a79b67b7aa6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# **Use .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**

# %%
bank_stocks.loc['2015'].xs(('BAC','Close'), axis=1).ta_plot(study='boll')
#shows the std of stocks as it moves out through time
# Out:
# <div>                            <div id="effb8988-e478-48de-ae81-173b6284651e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
